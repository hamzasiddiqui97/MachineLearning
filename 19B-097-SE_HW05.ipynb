# %%
#!/usr/bin/env python
# coding: utf-8

# %% [markdown]
# # HOMEWORK TASKS:

# %% [markdown]
# In[15]:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_selection import mutual_info_classif

# %% [markdown]
# In[16]:

# %%
get_ipython().system('pip install sklearn')
# Out:
# Requirement already satisfied: sklearn in c:\users\hamza\appdata\local\programs\python\python310\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\hamza\appdata\local\programs\python\python310\lib\site-packages (from sklearn) (1.1.1)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\hamza\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\hamza\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.8.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\hamza\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.22.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hamza\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (3.1.0)

# %% [markdown]
# # TASK 1:

# %% [markdown]
# In[ ]:

# %%
import pandas as pd 
from sklearn.preprocessing import LabelEncoder
col_names = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
data = pd.read_csv('housing.csv',names=col_names,header=None, delimiter=r"\s+")
df = pd.DataFrame(data)
# 2. split data into descriptive and target features in X and y variables respectively .
X = df .iloc [: ,1:12]
le = LabelEncoder()
df.iloc[:,13] = le.fit_transform(df.iloc[:,13])
Y = df . iloc [: ,13]
# 3. load important libraries
from sklearn.linear_model import LogisticRegression
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
# 4. Apply Model
lr = LogisticRegression ( class_weight ="balanced", solver ="lbfgs", random_state=42 , n_jobs = -1 , max_iter =500)
lr.fit(X,Y)
# 5. Select best features
bfs = SFS (lr ,
           k_features ='best',
           forward = True ,
           floating = False ,
           verbose =2 ,
           scoring ='accuracy',
           cv =0)
bfs.fit (X , Y )
# 6. print feature list
features = list ( bfs.k_feature_names_ )
print (features)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   12.4s finished
#
# [2022-07-05 20:34:15] Features: 1/11 -- score: 0.029644268774703556[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   20.4s finished
#
# [2022-07-05 20:34:35] Features: 2/11 -- score: 0.08300395256916997[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   20.2s finished
#
# [2022-07-05 20:34:55] Features: 3/11 -- score: 0.15217391304347827[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   17.3s finished
#
# [2022-07-05 20:35:13] Features: 4/11 -- score: 0.1976284584980237[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   18.1s finished
#
# [2022-07-05 20:35:31] Features: 5/11 -- score: 0.21936758893280633[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   16.1s finished
#
# [2022-07-05 20:35:47] Features: 6/11 -- score: 0.24308300395256918[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   12.5s finished
#
# [2022-07-05 20:36:00] Features: 7/11 -- score: 0.2628458498023715[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    8.4s finished
#
# [2022-07-05 20:36:08] Features: 8/11 -- score: 0.274703557312253[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    6.5s finished
#
# [2022-07-05 20:36:15] Features: 9/11 -- score: 0.2826086956521739[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.4s finished
#
# [2022-07-05 20:36:19] Features: 10/11 -- score: 0.2826086956521739[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ['INDUS', 'CHAS', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B']
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.3s finished
#
# [2022-07-05 20:36:21] Features: 11/11 -- score: 0.2766798418972332

# %% [markdown]
# # TASK 2:

# %% [markdown]
# In[ ]:

# %%
import pandas as pd 
from sklearn.preprocessing import LabelEncoder
col_names = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
data = pd.read_csv('housing.csv',names=col_names,header=None, delimiter=r"\s+")
df = pd.DataFrame(data)
# 2. split data into descriptive and target features in X and y variables respectively .
X = df .iloc [: ,1:12]
le = LabelEncoder()
df.iloc[:,13] = le.fit_transform(df.iloc[:,13])
Y = df . iloc [: ,13]
# 3. load important libraries
from sklearn.linear_model import LogisticRegression
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
# 4. Apply Model
lr = LogisticRegression ( class_weight ="balanced", solver ="lbfgs", random_state=42 , n_jobs = -1 , max_iter =500)
lr.fit(X,Y)
# 5. Select best features
bfs = SFS (lr ,
           k_features ='best',
           forward = True ,
           floating = False ,
           verbose =2 ,
           scoring ='accuracy',
           cv =0)
bfs.fit (X , Y )
# 6. print feature list
features = list ( bfs.k_feature_names_ )
print (features)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   11.7s finished
#
# [2022-07-05 20:25:36] Features: 1/11 -- score: 0.029644268774703556[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   17.7s finished
#
# [2022-07-05 20:25:54] Features: 2/11 -- score: 0.08300395256916997[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   17.6s finished
#
# [2022-07-05 20:26:11] Features: 3/11 -- score: 0.15217391304347827[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   15.6s finished
#
# [2022-07-05 20:26:27] Features: 4/11 -- score: 0.1976284584980237[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   13.7s finished
#
# [2022-07-05 20:26:41] Features: 5/11 -- score: 0.21936758893280633[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   14.8s finished
#
# [2022-07-05 20:26:56] Features: 6/11 -- score: 0.24308300395256918[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    9.6s finished
#
# [2022-07-05 20:27:06] Features: 7/11 -- score: 0.2628458498023715[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    8.1s finished
#
# [2022-07-05 20:27:14] Features: 8/11 -- score: 0.274703557312253[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.9s finished
#
# [2022-07-05 20:27:20] Features: 9/11 -- score: 0.2826086956521739[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.2s finished
#
# [2022-07-05 20:27:23] Features: 10/11 -- score: 0.2826086956521739[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ['INDUS', 'CHAS', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B']
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s finished
#
# [2022-07-05 20:27:25] Features: 11/11 -- score: 0.2766798418972332

# %% [markdown]
# # TASK 3: EXHAUSTIVE FEATURE SELECTION

# %% [markdown]
# In[18]:

# %%
import pandas as pd 
from sklearn.preprocessing.label import LabelEncoder
df=pd.read_csv('MIFClaimABTFull.csv')
X = df.iloc [: ,1:12]
le = LabelEncoder()
df.iloc[:,13] = le.fit_transform(df.iloc[:,13])
Y = df . iloc [: ,13]
from mlxtend.feature_selection import ExhaustiveFeatureSelector as EFS
from sklearn.neighbors import KNeighborsClassifier
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [23], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 from sklearn.preprocessing.label import LabelEncoder
#       3 df=pd.read_csv('MIFClaimABTFull.csv')
#       4 X = df.iloc [: ,1:12]
#
# ModuleNotFoundError: No module named 'sklearn.preprocessing.label'

# %%
knn = KNeighborsClassifier(n_neighbors=3)
efs1 = EFS (knn,min_features =1 ,max_features =4,scoring ='accuracy',print_progress=True,cv=5)
efs1 = efs1.fit(X,Y)
print ('Best accuracy score: %.2f'% efs1.best_score_)
print ('Best subset (indices):',efs1.best_idx_ )
print ('Best subset (corresponding names ):',efs1.best_feature_names_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 knn = KNeighborsClassifier(n_neighbors=3)
#       2 efs1 = EFS (knn,min_features =1 ,max_features =4,scoring ='accuracy',print_progress=True,cv=5)
#       3 efs1 = efs1.fit(X,Y)
#
# NameError: name 'KNeighborsClassifier' is not defined

# %% [markdown]
# # TASK 4:

# %% [markdown]
# In[19]:

# %% [markdown]
# Recursive Feature Elimination:

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('BreastCancerData.csv')
df = pd.DataFrame(data)
X=df.drop(['id','diagnosis'],axis=1)
X.head()
Y=df['diagnosis']
features = X.columns
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.30,random_state =42)
from sklearn . pipeline import Pipeline
from sklearn . model_selection import RepeatedStratifiedKFold
from sklearn . model_selection import cross_val_score
from sklearn . feature_selection import RFE
import numpy as np
from sklearn . ensemble import GradientBoostingClassifier
# initialize recursive feature elimination class
rfe = RFE ( estimator = GradientBoostingClassifier () , n_features_to_select =6)
model = GradientBoostingClassifier ()
# make a piline for execution
pipe = Pipeline ([('Feature Selection',rfe),('Model',model)])
cv = RepeatedStratifiedKFold ( n_splits =10 , n_repeats =5 , random_state=36851234)
# compute and print score of each feature
n_scores = cross_val_score(pipe,X,Y, scoring ='accuracy', cv=cv , n_jobs = -1)
print (np.mean (n_scores))
# Execute RFE model
pipe.fit (X, Y)
rfe.support_
rfe . support_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 21>()
#      19 cv = RepeatedStratifiedKFold ( n_splits =10 , n_repeats =5 , random_state=36851234)
#      20 # compute and print score of each feature
# ---> 21 n_scores = cross_val_score(pipe,X,Y, scoring ='accuracy', cv=cv , n_jobs = -1)
#      22 print (np.mean (n_scores))
#      23 # Execute RFE model
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:515, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     512 # To ensure multimetric format is not supported
#     513 scorer = check_scoring(estimator, scoring=scoring)
# --> 515 cv_results = cross_validate(
#     516     estimator=estimator,
#     517     X=X,
#     518     y=y,
#     519     groups=groups,
#     520     scoring={"score": scorer},
#     521     cv=cv,
#     522     n_jobs=n_jobs,
#     523     verbose=verbose,
#     524     fit_params=fit_params,
#     525     pre_dispatch=pre_dispatch,
#     526     error_score=error_score,
#     527 )
#     528 return cv_results["test_score"]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:285, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     265 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
#     266 results = parallel(
#     267     delayed(_fit_and_score)(
#     268         clone(estimator),
#    (...)
#     282     for train, test in cv.split(X, y, groups)
#     283 )
# --> 285 _warn_or_raise_about_fit_failures(results, error_score)
#     287 # For callabe scoring, the return type is only know after calling. If the
#     288 # return type is a dictionary, the error scores can now be inserted with
#     289 # the correct key.
#     290 if callable(scoring):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:367, in _warn_or_raise_about_fit_failures(results, error_score)
#     360 if num_failed_fits == num_fits:
#     361     all_fits_failed_message = (
#     362         f"\nAll the {num_fits} fits failed.\n"
#     363         "It is very likely that your model is misconfigured.\n"
#     364         "You can try to debug the error by setting error_score='raise'.\n\n"
#     365         f"Below are more details about the failures:\n{fit_errors_summary}"
#     366     )
# --> 367     raise ValueError(all_fits_failed_message)
#     369 else:
#     370     some_fits_failed_message = (
#     371         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     372         "The score on these train-test partitions for these parameters"
#    (...)
#     376         f"Below are more details about the failures:\n{fit_errors_summary}"
#     377     )
#
# ValueError:
# All the 50 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Hamza\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hamza\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 378, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Hamza\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 336, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "C:\Users\Hamza\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Hamza\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 870, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Hamza\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 870, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Hamza\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_selection\_rfe.py", line 235, in fit
#     return self._fit(X, y, **fit_params)
#   File "C:\Users\Hamza\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_selection\_rfe.py", line 244, in _fit
#     X, y = self._validate_data(
#   File "C:\Users\Hamza\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 596, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Hamza\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py", line 1074, in check_X_y
#     X = check_array(
#   File "C:\Users\Hamza\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py", line 899, in check_array
#     _assert_all_finite(
#   File "C:\Users\Hamza\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py", line 146, in _assert_all_finite
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# RFE does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %% [markdown]
# # TASK 5:LASSO REGRESSION<br>

# %% [markdown]
# In[9]:

# %%
col_names = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
data = pd.read_csv('housing.csv',names=col_names,header=None, delimiter=r"\s+")
df = pd.DataFrame(data)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
import numpy as np
from sklearn . pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso,Ridge

# %%
X = df .iloc [: ,1:12]
Y = df . iloc [: ,13]
features = X.columns
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size =0.33,random_state =42)
pipeline = Pipeline ([('scaler', StandardScaler()),('model',Lasso())])
search = GridSearchCV(pipeline,{'model__alpha':np.arange(0.1,10 ,0.1)},cv=5,scoring ="neg_mean_squared_error",verbose=3)
search.fit(X_train,y_train)
coefficients = search.best_estimator_.named_steps['model']. coef_
importance = np.abs(coefficients)
print(importance)
print(np.array(features)[importance > 0])
# Out:
# Fitting 5 folds for each of 99 candidates, totalling 495 fits
# [CV 1/5] END ................model__alpha=0.1;, score=-45.733 total time=   0.0s
# [CV 2/5] END ................model__alpha=0.1;, score=-31.052 total time=   0.0s
# [CV 3/5] END ................model__alpha=0.1;, score=-32.091 total time=   0.0s
# [CV 4/5] END ................model__alpha=0.1;, score=-22.967 total time=   0.0s
# [CV 5/5] END ................model__alpha=0.1;, score=-25.523 total time=   0.0s
# [CV 1/5] END ................model__alpha=0.2;, score=-45.877 total time=   0.0s
# [CV 2/5] END ................model__alpha=0.2;, score=-31.239 total time=   0.0s
# [CV 3/5] END ................model__alpha=0.2;, score=-33.558 total time=   0.0s
# [CV 4/5] END ................model__alpha=0.2;, score=-22.901 total time=   0.0s
# [CV 5/5] END ................model__alpha=0.2;, score=-25.580 total time=   0.0s
# [CV 1/5] END model__alpha=0.30000000000000004;, score=-46.441 total time=   0.0s
# [CV 2/5] END model__alpha=0.30000000000000004;, score=-31.739 total time=   0.0s
# [CV 3/5] END model__alpha=0.30000000000000004;, score=-35.393 total time=   0.0s
# [CV 4/5] END model__alpha=0.30000000000000004;, score=-23.319 total time=   0.0s
# [CV 5/5] END model__alpha=0.30000000000000004;, score=-25.899 total time=   0.0s
# [CV 1/5] END ................model__alpha=0.4;, score=-47.316 total time=   0.0s
# [CV 2/5] END ................model__alpha=0.4;, score=-32.551 total time=   0.0s
# [CV 3/5] END ................model__alpha=0.4;, score=-37.421 total time=   0.0s
# [CV 4/5] END ................model__alpha=0.4;, score=-24.086 total time=   0.0s
, score=-122.019 total time=   0.0s
# [CV 4/5] END ................model__alpha=9.3;, score=-69.728 total time=   0.0s
# [CV 5/5] END ................model__alpha=9.3;, score=-73.575 total time=   0.0s
# [CV 1/5] END ...............model__alpha=9.4;, score=-103.977 total time=   0.0s
# [CV 2/5] END ................model__alpha=9.4;, score=-73.080 total time=   0.0s
# [CV 3/5] END ...............model__alpha=9.4;, score=-122.019 total time=   0.0s
# [CV 4/5] END ................model__alpha=9.4;, score=-69.728 total time=   0.0s
# [CV 5/5] END ................model__alpha=9.4;, score=-73.575 total time=   0.0s
# [CV 1/5] END ...............model__alpha=9.5;, score=-103.977 total time=   0.0s
# [CV 2/5] END ................model__alpha=9.5;, score=-73.080 total time=   0.0s
# [CV 3/5] END ...............model__alpha=9.5;, score=-122.019 total time=   0.0s
# [CV 4/5] END ................model__alpha=9.5;, score=-69.728 total time=   0.0s
# [CV 5/5] END ................model__alpha=9.5;, score=-73.575 total time=   0.0s
# [CV 1/5] END ...............model__alpha=9.6;, score=-103.977 total time=   0.0s
# [CV 2/5] END ................model__alpha=9.6;, score=-73.080 total time=   0.0s
# [CV 3/5] END ...............model__alpha=9.6;, score=-122.019 total time=   0.0s
# [CV 4/5] END ................model__alpha=9.6;, score=-69.728 total time=   0.0s
# [CV 5/5] END ................model__alpha=9.6;, score=-73.575 total time=   0.0s
# [CV 1/5] END .model__alpha=9.700000000000001;, score=-103.977 total time=   0.0s
# [CV 2/5] END ..model__alpha=9.700000000000001;, score=-73.080 total time=   0.0s
# [CV 3/5] END .model__alpha=9.700000000000001;, score=-122.019 total time=   0.0s
# [CV 4/5] END ..model__alpha=9.700000000000001;, score=-69.728 total time=   0.0s
# [CV 5/5] END ..model__alpha=9.700000000000001;, score=-73.575 total time=   0.0s
# [CV 1/5] END ...............model__alpha=9.8;, score=-103.977 total time=   0.0s
# [CV 2/5] END ................model__alpha=9.8;, score=-73.080 total time=   0.0s
# [CV 3/5] END ...............model__alpha=9.8;, score=-122.019 total time=   0.0s
# [CV 4/5] END ................model__alpha=9.8;, score=-69.728 total time=   0.0s
# [CV 5/5] END ................model__alpha=9.8;, score=-73.575 total time=   0.0s
# [CV 1/5] END ...............model__alpha=9.9;, score=-103.977 total time=   0.0s
# [CV 2/5] END ................model__alpha=9.9;, score=-73.080 total time=   0.0s
# [CV 3/5] END ...............model__alpha=9.9;, score=-122.019 total time=   0.0s
# [CV 4/5] END ................model__alpha=9.9;, score=-69.728 total time=   0.0s
# [CV 5/5] END ................model__alpha=9.9;, score=-73.575 total time=   0.0s
# [0.15852218 0.         1.20200259 2.1456622  4.69649078 1.33319604
#  2.32562001 0.         0.25900608 2.18598266 1.36481534]
# ['ZN' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'TAX' 'PTRATIO' 'B']

# %% [markdown]
# # TASK 6:RANDOM FOREST FEATURE SELECTION

# %% [markdown]
# In[5]:

# %%
import pandas as pd
df = pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# In[6]:

# %%
import pandas as pd
#Random forest features selection
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
features = df.columns
X = df.iloc[: ,1:7]
y = df.iloc[: ,8]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size =0.33,random_state=42)
rf = RandomForestRegressor(random_state=42)
rf.fit(X_train,y_train)
rf.feature_importances_
# Out:
# array([0.40116215, 0.10453083, 0.07641024, 0.07469757, 0.18449002,
#        0.1587092 ])

# %% [markdown]
# In[7]:

# %%
import matplotlib.pyplot as plt
f_i = list(zip(features,rf.feature_importances_))
f_i.sort(key=lambda x:x[1])
plt.barh([x[0] for x in f_i],[x[1] for x in f_i])
plt.show()

# %% [markdown]
# In[ ]:
